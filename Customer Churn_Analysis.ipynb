# %% [markdown]
# <a href="https://colab.research.google.com/github/tanushreeip2004-cmd/Data-Analytics-Projects/blob/main/CC_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # LOADING THE DATASET

# %%
df = pd.read_csv('/content/Customer Churn.csv')
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# # INSPECTION OF DATA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# Calculating the total number of customers
total_customers = len(df)

# %%
total_customers
# Out:
# 7043

# %%
#Counting the number of customers who churned
churned_customers = df[df['Churn'] == 'Yes'].shape[0]

# %%
# Calculating the overall churn rate
overall_churn_rate = (churned_customers / total_customers) * 100

# %%
overall_churn_rate
# Out:
# 26.536987079369588

# %%
churned_customers
# Out:
# 1869

# %%
df['TotalCharges'] = df['TotalCharges'].replace(" ", "0")

# %%
print(df['TotalCharges'].isnull().sum())
# Out:
# 0

# %%
df.dropna(inplace= True)

# %%
print(df['TotalCharges'].isnull().sum())
# Out:
# 0

# %%
df['TotalCharges'] = df['TotalCharges'].astype(float)

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['customerID'].duplicated().sum()
# Out:
# np.int64(0)

# %%
#using if else condition
def cov(value):
  if value == 1:
      return 'yes'
  else :
    return 'no'
df['SeniorCitizen	'] = df['SeniorCitizen'].apply(cov)

# %%
# using lambda funtion
df['SeniorCitizen	'] = df['SeniorCitizen'].apply(lambda x: 'yes' if x == 1 else 'no')

# %% [markdown]
# ## UNCOVERING CUSTOMERS CHURNS

# %%
ax= sns.countplot(x= 'Churn' , data= df)
ax.bar_label(ax.containers[0])
plt.title("Count of customers by Churn")
plt.show()

# %%
gb = df.groupby('Churn').agg({'Churn':"count"})
gb
#plt.pie(df['Churn'])
#plt.show()
# Out:
#        Churn
# Churn
# No      5174
# Yes     1869

# %%
plt.figure(figsize=(4, 4))
gb = df.groupby('Churn').agg({'Churn':"count"})
gb
plt.pie(gb['Churn'],labels= gb.index,autopct="%1.2f%%")
plt.title("Percentage of Churned customers",fontsize=10)
plt.show()

# %%
# we counted the no of male and female along with no of churned females and males
plt.figure(figsize=(4, 4))
sns.countplot(x = "gender", data = df, hue = "Churn")
plt.title("Churn by Gender")
plt.show()

# %%
plt.figure(figsize=(4, 4))
sns.countplot(x = "SeniorCitizen", data = df, hue = "Churn")
plt.title("Churn by SeniorCitizen")
plt.show()

# %%
plt.figure(figsize=(4, 4))
ax = sns.countplot(x = "SeniorCitizen", data = df)
ax.bar_label(ax.containers[0])
plt.title("Churn by SeniorCitizen")
plt.show()

# %%
counts = df.groupby(["SeniorCitizen", "Churn"]).size().reset_index(name="count")
totals = counts.groupby("SeniorCitizen")["count"].transform("sum")
counts["percent"] = counts["count"] / totals * 100

pivot = counts.pivot(index="SeniorCitizen", columns="Churn", values="percent")

ax = pivot.plot(kind="bar", stacked=True, figsize=(5,5), colormap="cividis")

for i, row in pivot.iterrows():
    cumulative = 0
    for churn, value in row.items():
        if not pd.isna(value):
            plt.text(i, cumulative + value/2, f"{value:.1f}%",
                     ha="center", va="center", color="white", fontsize=10)
            cumulative += value

plt.title("Churn % by SeniorCitizen")
plt.ylabel("Percentage")
plt.xlabel("SeniorCitizen (0 = No, 1 = Yes)")
plt.legend(title="Churn")
plt.show()

# %%
# comparatively a greater percentage people in senior citizen category have churned

# %%
plt.figure(figsize=(9, 4))
sns.histplot(x = "tenure", data = df,bins = 50,hue= "Churn")
plt.show()

# %%
# the histogram shows that customers who have stayed for the longest have stayed and people who just started
# using the services have churned out

# %%
plt.figure(figsize=(4, 4))
ax = sns.countplot(x = "Contract", data = df, hue= "Churn")
ax.bar_label(ax.containers[0])
plt.title("Churn by Contract")
plt.show()

# %%
# people have month-to-month are likely to churned than who have year long contract

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'SeniorCitizen\t'],
#       dtype='object')

# %%
cols = [
    'PhoneService', 'MultipleLines', 'InternetService',
    'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
    'TechSupport', 'StreamingTV', 'StreamingMovies'
]

# Define subplot grid (3 rows × 3 columns since you have 9 features)
fig, axes = plt.subplots(3, 3, figsize=(15, 12))
axes = axes.flatten()  # flatten 2D array of axes into 1D for easy looping

# Loop through columns and create countplots
for i, col in enumerate(cols):
    sns.countplot(x=col, data=df, hue="Churn", ax=axes[i])
    axes[i].set_title(f"{col} by Churn")
    axes[i].set_xlabel("")
    axes[i].set_ylabel("Count")

# Hide any unused axes (in case cols < grid size)
for j in range(len(cols), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))
ax = sns.countplot(x = "PaymentMethod", data = df, hue= "Churn")
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
plt.xticks(rotation=45)
plt.title("Churn by PaymentMethod")
plt.show()

# %%
# people are likely to get churned when they are using the electronic payment method

# %%
#importing the data
df.to_csv('Customer Churn EDA.csv')
